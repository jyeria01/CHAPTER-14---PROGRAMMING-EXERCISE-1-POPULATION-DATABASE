# %% [markdown]
# # Make sure you have downloaded the book’s source code from the companion website at www.pearson.com/gaddis. In this chapter’s source code folder, you will find a program named create_cities_db.py. Run the program. The program will create a database named cities.db. The  database will have a table named Cities , with the following columns:
# # CityID - INTERGER PRIMARY KEY
# # CityName - TEXT
# # Population - REAL
# # The CityName column stores the name of a city and the Population column stores the population of that city. After you run the create_cities_db.py  program, the Cities table will contain 20 rows with various cities and their populations.Next, write a program that connects to the cities.db database, and allows the user to select any of the following operations:
#
# # Display a list of cities sorted by population, in ascending order.
# # Display a list of cities sorted by population, in descending order.
# # Display a list of cities sorted by name.
# # Display the total population of all the cities.
# # Display the average population of all the cities.
# # Display the city with the highest population.
# # Display the city with the lowest population.

# %% [markdown]
# # ALGORITHM

# %%
# Import sqlite3 module
# Function to connect to the cities.db database
# Connect to database
# Create the cursor
# Function to display cities sorted by population or name
# Display a list of cities by population or name
# Ascending order
# Descending order
# Name
# Function to display the total population of all cities
# Display the total population of all cities
# Function to display the average populaton of all cities
# Display the average poulation of all cities
# Function to display the city with the highest population
# Function to display the city with the lowest population
# Display the city with the lowest population
# Main
# Connect to database
# Display options
# User input choice
# Opertaion of selection
# Close connection
# Call the main function

# %%
# Import sqlite3 module
import sqlite3

# Function to connect to the cities.db database
def connect_to_database():
    # Connect to database
    conn = sqlite3.connect('cities.db')
    # Create the cursor
    cur = conn.cursor()
    return conn, cur

# Function to display cities sorted by population or name
def display_sorted_cities(cur, orders='ASC'):
    # Display a list of cities by population or name
    # Ascending order
    if orders == 'ASC':
        cur.execute('SELECT * FROM Cities ORDER by Population ASC')
    # Descending order
    elif orders == 'DESC':
        cur.execute('SELECT * FROM Cities ORDER by Population DESC')
    # Name
    elif orders == 'NAME':
        cur.execute('SELECT * FROM Cities ORDER by CityName ASC')
    else:
        print("Invalid order specified.")
        return
    # Fetch all rows from the cursor
    results = cur.fetchall()
    # Print a newline and the text "cities"
    print('\nCities:')
    # Iterate through each row in the results
    for row in results:
        # Print city name and Population
        print(f'{row[1]:20}Population: {row[2]:,.0f}')

# Function to display the city with the highest population
def display_highest_population_city(cur):
    # Display the city with the highest population
    cur.execute('SELECT * FROM Cities ORDER BY Population DESC LIMIT 1')
    highest_population = cur.fetchone()
    print(f'\nCity with the Highest Population:')
    print(f'{highest_population[1]} (Population: {highest_population[2]:,.0f})')

# Function to display the city with the lowest population
def display_lowest_population_cities(cur):
    # Display the city with the lowest population
    cur.execute('SELECT * FROM Cities ORDER BY Population ASC LIMIT 1')
    lowest_population = cur.fetchone()
    print(f'\nCity with the Lowest Population:')
    print(f'{lowest_population[1]} (Population: {lowest_population[2]:,.0f})')

# Main
def main():
    # Connect to database
    conn, cur = connect_to_database()

    # Display options
    while True:
        print("\nOperations:")
        print("1. Display cities sorted by population (ascending)")
        print("2. Display cities sorted by population (descending)")
        print("3. Display cities sorted by name")
        print("4. Display total population of all cities")
        print("5. Display average population of all cities")
        print("6. Display city with the highest population")
        print("7. Display city with the lowest population")
        print("8. Exit")

        # User input choice
        choice = input("Enter your choice (1-8): ")

        # Operation selection
        if choice == '1':
            display_sorted_cities(cur, 'ASC')
        elif  choice == '2':
            display_sorted_cities(cur, 'DESC')
        elif  choice == '3':
            display_sorted_cities(cur, 'NAME')
        elif  choice == '4':
            display_total_population(cur)
        elif  choice == '5':
            display_average_population(cur)
        elif  choice == '6':
            display_highest_population_city(cur)
        elif  choice == '7':
            display_lowest_population_cities(cur)
        elif  choice == '8':
            break
        else:
            print("Invalid choice. Please enter a number from 1 to 8.")

    # Close the connection
    conn.close()

# Call the main function if the script is executed
if __name__ == "__main__":
    main()
# I TOOK CHATGPT SUGGESTIONS TO MAKE CODE WORK CORRECTLY from Previous commit
# Out:
# Operations:
# 1. Display cities sorted by population (ascending)
# 2. Display cities sorted by population (descending)
# 3. Display cities sorted by name
# 4. Display total population of all cities
# 5. Display average population of all cities
# 6. Display city with the highest population
# 7. Display city with the lowest population
# 8. Exit
# Enter your choice (1-8): 1
#
# Cities:
# Guangzhou           Population: 12,458,130
# Rio de Janeiro      Population: 12,902,306
# Manila              Population: 12,946,263
# Lagos               Population: 13,122,829
# Chongqing           Population: 13,331,579
# Istanbul            Population: 14,163,989
# Kolkata             Population: 14,864,919
# Buenos Aires        Population: 15,180,176
# Karachi             Population: 16,617,644
# Dhaka               Population: 17,598,228
# New York            Population: 18,593,220
# Cairo               Population: 18,771,769
# Osaka               Population: 20,237,645
# Beijing             Population: 20,383,994
# Mexico City         Population: 20,998,543
# Mumbai              Population: 21,042,538
# Sao Paulo           Population: 21,066,245
# Shanghai            Population: 23,740,778
# Delhi               Population: 25,703,168
# Tokyo               Population: 38,001,000
#
# Operations:
# 1. Display cities sorted by population (ascending)
# 2. Display cities sorted by population (descending)
# 3. Display cities sorted by name
# 4. Display total population of all cities
# 5. Display average population of all cities
# 6. Display city with the highest population
# 7. Display city with the lowest population
# 8. Exit
# Enter your choice (1-8): 2
#
# Cities:
# Tokyo               Population: 38,001,000
# Delhi               Population: 25,703,168
# Shanghai            Population: 23,740,778
# Sao Paulo           Population: 21,066,245
# Mumbai              Population: 21,042,538
# Mexico City         Population: 20,998,543
# Beijing             Population: 20,383,994
# Osaka               Population: 20,237,645
# Cairo               Population: 18,771,769
# New York            Population: 18,593,220
# Dhaka               Population: 17,598,228
# Karachi             Population: 16,617,644
# Buenos Aires        Population: 15,180,176
# Kolkata             Population: 14,864,919
# Istanbul            Population: 14,163,989
# Chongqing           Population: 13,331,579
# Lagos               Population: 13,122,829
# Manila              Population: 12,946,263
# Rio de Janeiro      Population: 12,902,306
# Guangzhou           Population: 12,458,130
#
# Operations:
# 1. Display cities sorted by population (ascending)
# 2. Display cities sorted by population (descending)
# 3. Display cities sorted by name
# 4. Display total population of all cities
# 5. Display average population of all cities
# 6. Display city with the highest population
# 7. Display city with the lowest population
# 8. Exit
# Enter your choice (1-8): 3
#
# Cities:
# Beijing             Population: 20,383,994
# Buenos Aires        Population: 15,180,176
# Cairo               Population: 18,771,769
# Chongqing           Population: 13,331,579
# Delhi               Population: 25,703,168
# Dhaka               Population: 17,598,228
# Guangzhou           Population: 12,458,130
# Istanbul            Population: 14,163,989
# Karachi             Population: 16,617,644
# Kolkata             Population: 14,864,919
# Lagos               Population: 13,122,829
# Manila              Population: 12,946,263
# Mexico City         Population: 20,998,543
# Mumbai              Population: 21,042,538
# New York            Population: 18,593,220
# Osaka               Population: 20,237,645
# Rio de Janeiro      Population: 12,902,306
# Sao Paulo           Population: 21,066,245
# Shanghai            Population: 23,740,778
# Tokyo               Population: 38,001,000
#
# Operations:
# 1. Display cities sorted by population (ascending)
# 2. Display cities sorted by population (descending)
# 3. Display cities sorted by name
# 4. Display total population of all cities
# 5. Display average population of all cities
# 6. Display city with the highest population
# 7. Display city with the lowest population
# 8. Exit
# Enter your choice (1-8): 4
#
# Total Population of All Cities: 371,724,963.00
#
# Operations:
# 1. Display cities sorted by population (ascending)
# 2. Display cities sorted by population (descending)
# 3. Display cities sorted by name
# 4. Display total population of all cities
# 5. Display average population of all cities
# 6. Display city with the highest population
# 7. Display city with the lowest population
# 8. Exit
# Enter your choice (1-8): 5
#
# Average Population of All Cities: 18,586,248.15
#
# Operations:
# 1. Display cities sorted by population (ascending)
# 2. Display cities sorted by population (descending)
# 3. Display cities sorted by name
# 4. Display total population of all cities
# 5. Display average population of all cities
# 6. Display city with the highest population
# 7. Display city with the lowest population
# 8. Exit
# Enter your choice (1-8): 6
#
# City with the Highest Population:
# Tokyo (Population: 38,001,000)
#
# Operations:
# 1. Display cities sorted by population (ascending)
# 2. Display cities sorted by population (descending)
# 3. Display cities sorted by name
# 4. Display total population of all cities
# 5. Display average population of all cities
# 6. Display city with the highest population
# 7. Display city with the lowest population
# 8. Exit
# Enter your choice (1-8): 7
#
# City with the Lowest Population:
# Guangzhou (Population: 12,458,130)
#
# Operations:
# 1. Display cities sorted by population (ascending)
# 2. Display cities sorted by population (descending)
# 3. Display cities sorted by name
# 4. Display total population of all cities
# 5. Display average population of all cities
# 6. Display city with the highest population
# 7. Display city with the lowest population
# 8. Exit
# Enter your choice (1-8): 8

# %% [markdown]
# # Module

# %%
import city_populations

def main():
    # Connect to the database
    conn, cur = city_populations.connect_to_database()

    while True:
        print("\nOperations:")
        print("1. Display cities sorted by population (ascending)")
        print("2. Display cities sorted by population (descending)")
        print("3. Display cities sorted by name")
        print("4. Display total population of all cities")
        print("5. Display average population of all cities")
        print("6. Display city with the highest population")
        print("7. Display city with the lowest population")
        print("8. Exit")

        choice = input("Enter your choice (1-8): ")

        if choice == '1':
            city_populations.display_sorted_cities(cur, 'ASC')
        elif  choice == '2':
            city_populations.display_sorted_cities(cur, 'DESC')
        elif  choice == '3':
            city_populations.display_sorted_cities(cur, 'NAME')
        elif  choice == '4':
            city_populations.display_total_population(cur)
        elif  choice == '5':
            city_populations.display_average_population(cur)
        elif  choice == '6':
            city_populations.display_highest_population_city(cur)
        elif  choice == '7':
            city_populations.display_lowest_population_cities(cur)
        elif  choice == '8':
            break
        else:
            print("Invalid choice. Please enter a number from 1 to 8.")

    # Close the connection
    conn.close()

if __name__ == "__main__":
    main()
# Out:
# Operations:
# 1. Display cities sorted by population (ascending)
# 2. Display cities sorted by population (descending)
# 3. Display cities sorted by name
# 4. Display total population of all cities
# 5. Display average population of all cities
# 6. Display city with the highest population
# 7. Display city with the lowest population
# 8. Exit
# Enter your choice (1-8): 1
#
# Cities:
# Guangzhou           Population: 12,458,130
# Rio de Janeiro      Population: 12,902,306
# Manila              Population: 12,946,263
# Lagos               Population: 13,122,829
# Chongqing           Population: 13,331,579
# Istanbul            Population: 14,163,989
# Kolkata             Population: 14,864,919
# Buenos Aires        Population: 15,180,176
# Karachi             Population: 16,617,644
# Dhaka               Population: 17,598,228
# New York            Population: 18,593,220
# Cairo               Population: 18,771,769
# Osaka               Population: 20,237,645
# Beijing             Population: 20,383,994
# Mexico City         Population: 20,998,543
# Mumbai              Population: 21,042,538
# Sao Paulo           Population: 21,066,245
# Shanghai            Population: 23,740,778
# Delhi               Population: 25,703,168
# Tokyo               Population: 38,001,000
#
# Operations:
# 1. Display cities sorted by population (ascending)
# 2. Display cities sorted by population (descending)
# 3. Display cities sorted by name
# 4. Display total population of all cities
# 5. Display average population of all cities
# 6. Display city with the highest population
# 7. Display city with the lowest population
# 8. Exit
# Enter your choice (1-8): 3
#
# Cities:
# Beijing             Population: 20,383,994
# Buenos Aires        Population: 15,180,176
# Cairo               Population: 18,771,769
# Chongqing           Population: 13,331,579
# Delhi               Population: 25,703,168
# Dhaka               Population: 17,598,228
# Guangzhou           Population: 12,458,130
# Istanbul            Population: 14,163,989
# Karachi             Population: 16,617,644
# Kolkata             Population: 14,864,919
# Lagos               Population: 13,122,829
# Manila              Population: 12,946,263
# Mexico City         Population: 20,998,543
# Mumbai              Population: 21,042,538
# New York            Population: 18,593,220
# Osaka               Population: 20,237,645
# Rio de Janeiro      Population: 12,902,306
# Sao Paulo           Population: 21,066,245
# Shanghai            Population: 23,740,778
# Tokyo               Population: 38,001,000
#
# Operations:
# 1. Display cities sorted by population (ascending)
# 2. Display cities sorted by population (descending)
# 3. Display cities sorted by name
# 4. Display total population of all cities
# 5. Display average population of all cities
# 6. Display city with the highest population
# 7. Display city with the lowest population
# 8. Exit
# Enter your choice (1-8): 2
#
# Cities:
# Tokyo               Population: 38,001,000
# Delhi               Population: 25,703,168
# Shanghai            Population: 23,740,778
# Sao Paulo           Population: 21,066,245
# Mumbai              Population: 21,042,538
# Mexico City         Population: 20,998,543
# Beijing             Population: 20,383,994
# Osaka               Population: 20,237,645
# Cairo               Population: 18,771,769
# New York            Population: 18,593,220
# Dhaka               Population: 17,598,228
# Karachi             Population: 16,617,644
# Buenos Aires        Population: 15,180,176
# Kolkata             Population: 14,864,919
# Istanbul            Population: 14,163,989
# Chongqing           Population: 13,331,579
# Lagos               Population: 13,122,829
# Manila              Population: 12,946,263
# Rio de Janeiro      Population: 12,902,306
# Guangzhou           Population: 12,458,130
#
# Operations:
# 1. Display cities sorted by population (ascending)
# 2. Display cities sorted by population (descending)
# 3. Display cities sorted by name
# 4. Display total population of all cities
# 5. Display average population of all cities
# 6. Display city with the highest population
# 7. Display city with the lowest population
# 8. Exit
# Enter your choice (1-8): 5
#
# Average Population of All Cities: 18,586,248.15
#
# Operations:
# 1. Display cities sorted by population (ascending)
# 2. Display cities sorted by population (descending)
# 3. Display cities sorted by name
# 4. Display total population of all cities
# 5. Display average population of all cities
# 6. Display city with the highest population
# 7. Display city with the lowest population
# 8. Exit
# Enter your choice (1-8): 8
